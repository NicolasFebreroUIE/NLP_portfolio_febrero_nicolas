# %% [markdown]
# # Exercises start
#
# Please solve this exercises. Do it **WITHOUT ANY AI HELP**.

# %%
# Exercise 1: Make Plurals
# Write a program to generate plural forms of English nouns from a given list of singular nouns.
# Simplification rules:
# 1. Add 's' to most words (e.g., "cat" -> "cats").
# 2. If the word ends with 'y' and is preceded by a consonant, replace 'y' with 'ies' (e.g., "baby" -> "babies").
# 3. If the word ends with 'f' or 'fe', replace it with 'ves' (e.g., "wolf" -> "wolves").
# 4. Add 'es' to words ending in 's', 'x', 'z', 'ch', or 'sh' (e.g., "box" -> "boxes").
# 5. For irregular nouns, handle exceptions (e.g., "child" -> "children", "man" -> "men").

nouns = ["cat", "baby", "wolf", "box", "child", "man", "mouse", "knife", "bush"]
irre = {"child": "children", "man": "men", "mouse": "mice"}
resultsEx1 = []

for noun in nouns:
    if noun in irre: 
        plural = irre[noun]
    elif  noun.endswith("f"):
        plural = noun [:-1] + "ves"
    elif noun.endswith("fe"):
        plural = noun [:-2] + "ves"
    elif noun.endswith("y"):
        plural = noun.replace("y", "ies")
    elif noun.endswith("sh"):
        plural = noun + "es"
    elif noun.endswith("x"):
        plural = noun + "es"
    elif noun.endswith("z"):
        plural = noun + "es"
    elif noun.endswith("ch"):
        plural = noun + "es"
    elif noun.endswith( "s"):
        plural = noun + "es"
    else:
        plural = noun + "s"
    print(f"{noun} -> {plural}")
    resultsEx1.append (f"{noun} -> {plural}")

# I´m going to create a list, that have the results of the plural form of the nouns, so i can
# later call it (the list) to get the RE form.  

# Now with regular expressions
import re
for i in resultsEx1:
    print(i)
# Out:
# cat -> cats
# baby -> babies
# wolf -> wolves
# box -> boxes
# child -> children
# man -> men
# mouse -> mice
# knife -> knives
# bush -> bushes
# cat -> cats
# baby -> babies
# wolf -> wolves
# box -> boxes
# child -> children
# man -> men
# mouse -> mice
# knife -> knives
# bush -> bushes

# %%
# Exercise 2: Extract Email Addresses
# Write a Python program to extract all email addresses from the following string.
text = "Please contact us at support@example.com, sales@example.org, or admin123@example.net for assistance."
for i in text.split():
    if "@" in i:
        print(i)

import re 

i = re.findall(r"[a-zA-Z0-9]+@[a-zA-Z0-9]+\.[a-z]+", text)
print(i)
# Out:
# support@example.com,
# sales@example.org,
# admin123@example.net
# ['support@example.com', 'sales@example.org', 'admin123@example.net']

# %%
# Exercise 3: Extract Hashtags
# From a tweet, extract all valid hashtags.
tweet = "Loving the #sunset at the #beach! But #123abc and ##double are #invalid#tags."

hashtags = []

for i in tweet.split():

    if i.startswith("#") and len(i) > 1 and i[1].isalpha() and i.count("#") == 1:
        
        clean = i.rstrip("!.,?")
        hashtags.append(clean)

print(hashtags)

# With Regular Expressions, and it shows me different results, as we can see Invalid and Tags separated, while with the nromal
# form they are not valid.
hashtagsRE = re.findall(r'(?<![#])#[a-zA-Z][a-zA-Z0-9]*', tweet)
print(hashtagsRE)
# Out:
# ['#sunset', '#beach']
# ['#sunset', '#beach', '#invalid', '#tags']
