# %% [markdown]
# # Speech Processing Lab Tasks

# %% [markdown]
# ### Exercise 1: Local Speech to Text

# %% [markdown]
# ### Exercise 2: Text to Speech
# Using gTTS for speech synthesis.

# %%
from gtts import gTTS
import os

mytext = 'Hello my beautiful class in Vigo!'
language = 'en'

myobj = gTTS(text=mytext, lang=language, slow=False)
myobj.save("Salute.mp3")
os.system("start welcome.mp3")

# %% [markdown]
# ### Exercise 3: External API Speech to Text

# %% [markdown]
# ### Exercise 4: External API Text to Speech

# %% [markdown]
# ### Exercise 5: Beyond STT and TTS - Sentiment Analysis
